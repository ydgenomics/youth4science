# %% [markdown]
# # Biological Statistics
# Teacher: Xuecong Liu
# Date: 202509-
# Context:
#   - Ch1. Basic Concepts 描述性统计
#   - Ch2. Probability Distribution 概率分布
#   - 假设检验
#   - 单样本均值比较
#   - 两个样本均值比较
#   - 多个独立样本均值比较
#   - 多因素方差分析
#   - 方差分析模型
#   - 多个相关样本均值比较
#   - 简单线性相关分析
#   - 一元线性回归分析
#   - 多元线性回归分析
#   - 协方差分析
#   - 偏相关分析
#   - 曲线估计
#   - 分类变量的回归分析
#   - 频数分析
#   - 存活分析
#   - 统计图制作

# %% [markdown]
# # Ch1. Basic Concepts
# It is usually not feasible or necessary to measure all elements in a population because of budget limit, logistical constraints, or topographical nonaccessibility. In most cases, we infer characteristics of a population being studied by analyzing characteristics of a representative sample.
# - **总体（population）** 根据研究目的确定的、符合指定条件的研究对象的全体，如北京地区人群，总体大小用*N*表示。
# - **样本（sample）** 根据一定原则从总体中抽取的一部分个体，样本大小用n表示
# - **参数（parameter）** 描述总体数量特征和规律的数值，也称总体特征数，如用υ表示总体平均数，用𝜎表示总体标准差。方差和标准差的区别？
# - **统计量（statistic）** 描述样本数量特征和规律的数值，也称样本特征数，如用(x上一横)表示样本平均数，用s表示样本样本标准差
# - **变量（variable）** 具有变异性的性状或特征，如性别、身高、体重、血压等，每次观测得到的值是随机的。可分为分类变量(计数数据/等级数据)和数值变量(计量数据)
#   - **分类变量（categorical variable）**
#     - **名义变量（nominal variable）** 无序分类变量，如性别、种族、颜色、血型等。
#     - **有序变量（ordinal variable）** 有序分类变量，如濒危等级（近危、异危、濒危、极危、绝灭）
#   - **数值变量（numerical variable）**
#     - **离散变量（discrete variable）** 只能取整数的数值变量，如母鸡的孵卵数
#     - **连续变量（continuous variable）** 可以在某一范围内取任何值的数值变量，如身高、血压等
# - **观测值（observed value）** 对某性状或特征进行观测得到的值
# - **误差（error）**
#   - **随机误差（random error, sampling error）**由无法控制的偶然因素造成的实验结果与真实值之间的差异
#   - **系统误差（systematic error）** 由试验条件不同造成的试验结果与真实值之间的差异，如仪器差异、研究人员习惯不同等。
# - **集中趋势的度量（measure of central tendency）**
#
# |度量名|解释|优点|缺点|
# |-|-|-|-|
# |平均数（mean）|总体平均数/样本平均数|计算涉及或利用所有观测值|对极值敏感|
# |中位数（median）|观测值从小到大排列，位于中间位置的值|对极值不敏感|取决于中间值，仅涉及数值的大小|
# |众数（mode）|出现次数最多的观测值，多用于分类数据的频率统计|-|-|
#
# - **离散趋势的度量（measure of dispersion）**
#
# |度量名|解释|优点|缺点|
# |-|-|-|-|
# |极差（range）最大值和最小值的差，记为*R*|容易计算|取决于最大值和最小值，仅涉及数值的大小|
# |百分位数（percentile）|观测值从小到大排列，位于*p*%位置的值称为第*p*百分位数|-|-|
# |正常范围（normal range）|百分之多少的观测值所在的范围|-|-|
# |四分位数（quartile）|下四分位数；中四分位数；上四分位数|-|-|
# |四分位差（interquartile range）|上四分位数与下四分位数的差值|-|-|
#
#
# -
#
#
#
# <details>
#   <summary>希腊字母</summary>
# α 阿尔法， β 贝塔， γ 伽玛，δ 德尔塔， ε 伊普西隆， ζ 泽塔， η 伊塔， θ 西塔， ι 约塔， κ 卡帕， λ 兰姆达，μ 米欧 ，ν 纽， ξ 克西， ο 欧米克隆， π 派， ρ 柔 ，σ 西格玛， τ 陶 ，υ 玉普西隆， φ 弗爱， χ 凯， ψ 普赛
#
# [24个希腊字母 附字母表](https://zhuanlan.zhihu.com/p/139789982)
# </details>

# %% [markdown]
# # Ch2. Probability distribution
#
# [扎马步-常用概率分布函数详解：R语言篇](https://mp.weixin.qq.com/s/zkhy84C3rEb-LeDKATqiog)
# [数据分布拟合](https://mp.weixin.qq.com/s/ZrCmdo1h4Fzby7MilCYzlQ)

# %% [markdown]
# ## 2.1 t distribution

# %% [markdown]
# ## 2.2 Chi-square distribution

# %% [markdown]
# ## 2.3 F distribution

# %% [markdown]
# ## 2.4 Bernoulli (two-point) distribution
#
# [终于把统计学中的伯努利分布搞懂了！！](https://mp.weixin.qq.com/s/vIZR8gMd7qqV1WvP3_D0ug)

# %% [markdown]
# ## 2.5 Bionomial distribution

# %% [markdown]
# ## 2.6 Geometric distribution

# %% [markdown]
# ## 2.7 Negative binomial distribution

# %% [markdown]
# ## 2.8 Hypergeometric distribution

# %% [markdown]
# ## 2.9 Poisson distribution

# %% [markdown]
# ## 2.10 Exponential distribution

# %% [markdown]
# ## 2.11 Gamma distribution

# %% [markdown]
# ## 2.12 Normal distribution

# %% [markdown]
# # Ch3. Hypothesis Testing
# *null hypothesis* (H<sub>0</sub>)
#
# Type Ⅰ & Ⅱ error
# Type Ⅰ error(α): The probability of rejecting H<sub>0</sub>, if H0 true. This is the significance level, usually set as 0.05 or 0.01
# Type Ⅱ error(β): The probability of accepting H0, if H0 is false. 1-β is the testing power, usually controlled as > 0.8
# [P-value, qvalue, FDR什么区别？总被审稿人提起的多重假设检验校正是什么？](https://mp.weixin.qq.com/s/JCgjUJ_v8FfTNGScqUC2bw)
#
# confidence interval

# %% [markdown]
# # Ch4. One Sample Average
# - One sample *t* test
# - Sign test (Binomial test)
